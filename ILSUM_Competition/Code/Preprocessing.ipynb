# %%
import pandas as pd

train_df = pd.read_csv('../Dataset/english_train.csv')
print(train_df.shape[0])
train_df.head()
# Out:
# 27843
#                      Id                                            Heading  \
# 0  english_2023_train_0  Barbie Review: Greta Gerwig, Margot Robbie, Ry...
# 1  english_2023_train_1  Gadar 2: Sunny Deol-Ameesha Patel Starrer's Tr...
# 2  english_2023_train_2  Kartik Aaryan Ditches First Class To Fly In Ec...
# 3  english_2023_train_3  India's Anju, Now Fatima, Receives Land, Money...
# 4  english_2023_train_4  Himachal Pradesh Hotels Offer 50% Discount As ...
#
#                                              Summary  \
# 0  Barbie Movie Review: Ryan Gosling shines the b...
# 1  A source close to the film told News18 exclusi...
# 2  Kartik Aaryan was spotted flying in economy cl...
# 3  Abbasi had said that it was important to make ...
# 4  Flash floods and landslides caused by heavy do...
#
#                                              Article Unnamed: 4 Unnamed: 5  \
# 0  Barbie Movie Review: One mention of Barbie and...        NaN        NaN
# ...

# %%
test_df = pd.read_csv ('../Dataset/EnglishNews_test.csv')
print(test_df.shape[0])
test_df.head()
# Out:
# 2895
#                    id                                            Article  \
# 0  EnglishNews_test_0  Chief Minister Mamata Banerjee-led West Bengal...
# 1  EnglishNews_test_1  If you are a Xiaomi Mi A3 user whose unit has ...
# 2  EnglishNews_test_2  Har Ghar Tiranga  is Prime Minister Narendra M...
# 3  EnglishNews_test_3  VidaHero MotoCorp is gearing up to expand its ...
# 4  EnglishNews_test_4  The Delhi High Court has permitted St Stephen'...
#
#                                              Heading
# 0  After Durga Puja, West Bengal Govt Eyes UNESCO...
# 1  Is Your Xiaomi Mi A3 Bricked Because of The Fa...
# 2  Har Ghar Tiranga Movement: Right Time for Indi...
# 3  Hero MotoCorp Plans to Expand its Electric Two...
# 4  Delhi HC Permits St Stephen's College to Hold ...

# %%
train_df = train_df[['Id', 'Heading', 'Summary', 'Article']]
print(train_df.shape[0])
train_df.head()
# Out:
# 27843
#                      Id                                            Heading  \
# 0  english_2023_train_0  Barbie Review: Greta Gerwig, Margot Robbie, Ry...
# 1  english_2023_train_1  Gadar 2: Sunny Deol-Ameesha Patel Starrer's Tr...
# 2  english_2023_train_2  Kartik Aaryan Ditches First Class To Fly In Ec...
# 3  english_2023_train_3  India's Anju, Now Fatima, Receives Land, Money...
# 4  english_2023_train_4  Himachal Pradesh Hotels Offer 50% Discount As ...
#
#                                              Summary  \
# 0  Barbie Movie Review: Ryan Gosling shines the b...
# 1  A source close to the film told News18 exclusi...
# 2  Kartik Aaryan was spotted flying in economy cl...
# 3  Abbasi had said that it was important to make ...
# 4  Flash floods and landslides caused by heavy do...
#
#                                              Article
# 0  Barbie Movie Review: One mention of Barbie and...
# 1  The highly anticipated Gadar 2, starring Sunny...
# ...
