# %%
import pandas as pd

# %%
# %run "Data_Preprocessing_2.ipynb"
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/akheel/.local/lib/python3.10/site-packages (2.1.1)
# Requirement already satisfied: numpy>=1.22.4 in /home/akheel/.local/lib/python3.10/site-packages (from pandas) (1.26.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/akheel/.local/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas) (2022.1)
# Requirement already satisfied: tzdata>=2022.1 in /home/akheel/.local/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
#
# [notice] A new release of pip is available: 23.3 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# " 551; AIR 1996 SC 463; 1995 (6) SCC 315; 1995 (7) JT 225; 1995 (5) SCALE 690 (11 October 1995) JEEVAN REDDY, B.P. (J) JEEVAN REDDY, B.P. (J) MAJMUDAR S.B. (J) CITATION: 1996 AIR 463 1995 SCC (6) [315 JT 1995] (7) 225 1995 SCALE (5)690 B.P. JEEVAN REDDY, J. This appeal is preferred against the judgment of the Andhra Pradesh High Court answering the question referred to it in the negative, i.e., against the Revenue and in favour of the assessee. The question referred is ""whether on the facts and in the circumstances of the case, the capital gain of Rs.58,000 was assessable in the hands of the assessee in terms of Section 64(1) (iv) of the Income Tax Act, 1961."" The assessment year concerned herein is 1966-67. Section 64(1) (iv), as it stood at the relevant time, read thus: ""64(1). In computing total income of any individual, there shall be included all such income as arises directly or directly -- (iv) subject to the provisions of clause (i) of section 27, to a minor child, not being a married daughter of such individual, from assets transferred directly or indirectly to the minor child by such individual otherwise than for adequate consideration. Reference to clause (i) of Section 27 is not necessary since it has no relevance to the facts of this case. The respondent-assessee is an individual. She was carrying on the business of mica mining and was also having income from property and money lending. During the financial year 1956-57, the respondent made a cash gift of Rupees ninety thousand to her minor son, Suryanarayana Reddy. This amount was immediately utilised for purchasing a house property at Gudur. The said house property was being utilised for the purpose of the assessee's business. Eight years after the purchase of the house, i.e., on July 5, 1967, the said house property was sold to Tirupati Devasthanam for a consideration of Rs.1,48,000/-. On the date of this sale also, Suryanarayana Reddy was a minor. The Income Tax Officer included the capital gain of Rs.58,000/- in the assessee's income in terms of Section 64(1), which was objected to by the assessee. Her appeal to the Appellate Assistant Commissioner was dismissed. Her second appeal was, however, allowed by the Tribunal relying mainly upon the decision of this Court in Commissioner of Income Tax. West Bengal-III v. Prem Bhai Parekh & Ors.[(1970) 77 I.T.R.27]. Thereupon, the said question was referred for the opinion of the High Court at the instance of the Revenue. The High Court too held in favour of the assessee, again relying mainly upon the decision in Prem Bhia Parekh. Sri J.Ramamurthy, learned counsel for the Revenue, submits that the High Court has misunderstood the ratio of Prem Bhai Parekh. He submits that the ratio of the said decision has no application herein. On the contrary, the learned counsel submits, the facts of Sevantilal Maneklal Sheth v. Commissioner of Income Tax (Central). Bombay [(1968) 68 I.T.R.503] are quite similar to the facts of this case and that the ratio of the said decision squarely governs it and concludes the issue in favour of the Revenue. Learned counsel also pointed out that the decision in Prem Bhai Parekh was explained and distinguished by this Court in Smt. Mohini Thapar v. Commissioner of Income Tax (Central). Calcutta & Ors. [(1972) 83 I.T.R.208]. Counsel submits that though both these decisions were brought to the notice of the High Court, it has erred in distinguishing these two decisions and in following Prem Bhai Parekh. We are inclined to agree with Sri Ramamurthy. Let us first see what does clause (iv) of Section 64(1) say. In computing the total income of an individual, it says, there shall be included all such income as arises directly or indirectly to a minor child (not being a married daughter of such individual) from assets transferred directly directly or indirectly to the minor child by such individual otherwise than for adequate consideration. The facts of this case squarely fall within the said rule.  ...
#
# len(documents_df):  2000
# documents_df.shape:  (2000, 2)
# len(queries_df):  200
# queries_df.shape:  (200, 2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in /home/akheel/.local/lib/python3.10/site-packages (3.8.1)
# Requirement already satisfied: click in /usr/lib/python3/dist-packages (from nltk) (8.0.3)
# Requirement already satisfied: joblib in /home/akheel/.local/lib/python3.10/site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/akheel/.local/lib/python3.10/site-packages (from nltk) (2023.10.3)
# Requirement already satisfied: tqdm in /home/akheel/.local/lib/python3.10/site-packages (from nltk) (4.66.1)
#
# [notice] A new release of pip is available: 23.3 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# [nltk_data] Downloading package stopwords to /home/akheel/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/akheel/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# {'ensemble', 'association3', 'honor', '2either', '1302', 'recruit', 'yeshwantpura', 'underwhich', 'annexure6', 'paniyas', 'jaganwohan', 'kahitish', 'jallandar', 'dibang', 'kirloskar', 'grie', 'fulfils', 'indispensably', 'air1919', 'dholkia', '500with', 'case4', 'heygate', 'ia131', 'workmenappellants', 'samajik', 'mohomedan', 'enacted', '19741975', '396b', 'sc2027', 'teain', '889ab', 'disposition', 'sectdamage', 'valueprice', 'er322', 'tenantrespondent', 'augment', '116th', 'authoyity', 'normandin', 'tarnished', 'takingcausing', 'saralaya', '13381356', 'televising', 'matrubhumi', 'uncovered', 'l9d4', 'remotely', 'corpus', 'ruleinquiry', '18fg20ef', 'exnecessitate', 'petuity', 'regada', 'headline', 'lawart', '1999071920010713200108151947', 'geostationary', '106bhomicharas', 'debarred', 'dombach', '199999', '29011964', '540489', 'realm', 'entia', 'carnatic', 'ltd19931', '768912', 'bakhshish', 'brood', '632d', 'lighting', '196768under', 'helper', 'member', 'vdk', 'awareness', 'rushed', 'militates', 'shujat', 'plaintifffor', 'quantify', 'intelligently', 'wrongful', 'net', 'conceptualism', 'feiture', 'negli', 'rowdyish', 'shidramappa', 'collocating', 'publicsafety', 'kilachand', 'paralysis', 'whippoorwill', 'convincingly', '1046fg', 'founda', 'antulay1984', 'obsequiel', 'bopade', 'shebaiti', 'prabhuji', 'undergoes', 'blanesburgh', '12111958', 'barneman', 'perferred', 'record', 'chalam', 'drunkenness', 'exchanging', 'ltd1958', 'shadowpublic', 'casesdiscretion', 'managementrespondent', 'denoted', 'ontariao', 'kassy', 'kilachands', 'scandalise', 'hyderabad1', 'inegalitarian', 'hurting', 'cornoration', 'articulated', 'bjelkepetersen', 'basak1', 'hat', 'tryst', 'christansen', 'rearrest', 'jivanrao', 'unfurnished', 'maximize', 'mirajkars', '71procedure', 'fractured', 'somuch', 'opinon', 'tumbein', 'despotism1', 'guptabesides', 'academy', 'tified', '849b', 'factsituations', 'leisure', '522h', 'inreply', 'lessas', 'disallows', 'rushing', 'legitimated', '19612scr459', '2au', 'understatutory', '15431546', '222338', 'rs1167959', '341the', 'noutw', 'mtcferozepur', 'decidedaward', 'duraipandi', '811986', 'ofinterim', 'romantic', 'abdullabhai', 'consci', 'operationif', 'preexecution', 'proclivity', '3131992', 'daktarji', 'inereasing', 'outright', 'ednbutterworths', 'goundain', 'berger', 'raghavachari', 'advocatcgeneral', 'iori', '2561973', 'proceduresanction', 'shuttle', 'mriduls', 'cliii', 'barams', 'villageofficers', 'anaro', 'ammonia', 'bijenananda', 'liar1', 'respendent', 'interventionists', 'talukdars', 'havildarclerk', '241985', 'sumaroo', 'kirkwood3', 'paritition', 'trisected', 'recueil', 'cryptic', 'fatherinlaws', 'intemperately', '626280', 'salvesen', 'simil', 'kripal', '5there', 'proposed', '198949', 'ch', 'stacking', '2ie', 'ejectmentbona', '1698', '2721969', '1171', 'itto', 'io7118', 'grantedbut', 'pk', '60000000', 'bradari', 'swaminatha', '9115', 'ncc1983865ini4', 'sc1914', 'drule', 'hara', 'defandant', 'shasikala', 'encumber', '9298', '25t', 'ushas', 'dhani', 'bhajahari', 'berlusconi', 'singh4o', 'chinubbai', 'customernaturally', 'hyderabadthe', 'anorder', 'geld', 'sucess', 'australia2', 'manwar', '11251', 'wouldand', 'vestigated', 'wright2', 'oreder', 'gule', '1558', 'soveriegn', 'resondents', '187678', 'rummaging', 'impiled', 'snkacker', '205g', 'riskbenefit', 'alimedabad', 'fonder', '40000being', '41625', 'surchange', '44219', 'satyaranjan', 'nutrient', 'dalbir', 'telegraphist', '15pw', 'monde', 'gokal', '02051955', 'ambivalent', 'intercostal', 'symmetry', 'demonstrating', 'obsession', 'ovi', 'mogh', 'hazari', 's431', 'colated', 'displacedhigh', 'luctant', '223d', 'courttrial', 'receveur', 'nila', '9169', 'salewhether', 'promotionnot', 'teagrowing', 'eclecticism', 'lefting', '141912', 'in_rajasthan', 'punjab1990', 'lawheld', 'retentionthanks', '2000per', 'entourage', 'tia', 'flourished', 'courtcertificate', 'unethical', 'subcluase', 'awardto', 'chowki', 'foreignerinternational', 'yv', '1195216983', '7900', 'nandalal', 'thairlwall ...
# 130730

# %%
documents_df = documents_df
documents_df
# Out:
#           Prior_Case_Name                                    Prior_Case_Text  \
# 0     prior_case_0001.txt   551; AIR 1996 SC 463; 1995 (6) SCC 315; 1995 ...
# 1     prior_case_0002.txt   [1974] INSC 106; AIR 1974 SC 1389; 1975 (1) S...
# 2     prior_case_0003.txt   SC 23; 1953 SCR 136 (30 October 1952) 30/10/1...
# 3     prior_case_0004.txt   271; 1957 SCR 208 (20 December 1956) 20/12/19...
# 4     prior_case_0005.txt   MAHAVIR SINGH & ORS [1988] INSC 17; AIR 1988 ...
# ...                   ...                                                ...
# 1995  prior_case_1891.txt   INSC 73; AIR 1959 SC 1194; 1960 (1) SCR 161 (...
# 1996  prior_case_1892.txt   1978 (3) SCR 691; 1978 (2) SCC 491 (18 April ...
# 1997  prior_case_1893.txt   166; AIR 1965 SC 568; 1964 (8) SCR 332 (29 Ju...
# 1998  prior_case_1894.txt   247; 1951 SCR 431 (27 March 1951) 27/03/1951 ...
# 1999  prior_case_1895.txt   1995 SC 1476; 1995 (4) SCC 141; 1995 (4) JT 3...
#
#                                       preprocessed_text
# 0     551 air 1996 sc 463 1995 6 scc 315 1995 7 jt 2...
# 1     1974 insc 106 air 1974 sc 1389 1975 1 scr 173 ...
# 2     sc 23 1953 scr 136 30 october 1952 30101952 ma...
# 3     271 1957 scr 208 20 december 1956 20121956 aiy...
# 4     mahavir singh or 1988 insc 17 air 1988 sc 637 ...
# ...                                                 ...
# 1995  insc 73 air 1959 sc 1194 1960 1 scr 161 8 may ...
# 1996  1978 3 scr 691 1978 2 scc 491 18 april 1978 kr...
# 1997  166 air 1965 sc 568 1964 8 scr 332 29 july 196...
# 1998  247 1951 scr 431 27 march 1951 27031951 mahaja...
# 1999  1995 sc 1476 1995 4 scc 141 1995 4 jt 34 1995 ...
#
# [2000 rows x 3 columns]

# %%
queries_df = queries_df
queries_df
# Out:
#          Current_Case_Name                                  Current_Case_Text  \
# 0    current_case_0001.txt  **Judgement** IN THE SUPREME COURT OF INDIA CI...
# 1    current_case_0002.txt  The petitioners in all these petitions, served...
# 2    current_case_0003.txt  These appeals are directed against the judgmen...
# 3    current_case_0004.txt  BACKGROUND FACTS: 'Nilgiris' is a hill distric...
# 4    current_case_0005.txt  **Judgement** IN THE SUPREME COURT OF INDIA CI...
# ..                     ...                                                ...
# 195  current_case_0148.txt  **Judgement** IN THE SUPREME COURT OF INDIA CI...
# 196  current_case_0149.txt  2\. The pivotal issue that emerges for conside...
# 197  current_case_0150.txt  ##  HARDEVINDER SINGH v. PARAMJIT SINGH & ORS....
# 198  current_case_0151.txt  **Judgement** IN THE SUPREME COURT OF INDIA CI...
# 199  current_case_0152.txt  TARUN CHATTERJEE & HARJIT SINGH BEDI CIVIL APP...
#
#                                      preprocessed_text
# 0    judgement supreme court india civil appellate ...
# 1    petitioner petition served medical dental vete...
# 2    appeal directed judgment high court bombay goa...
# 3    background fact nilgiris hill district state t...
# 4    judgement supreme court india civil appellate ...
# ..                                                 ...
# 195  judgement supreme court india civil appellate ...
# 196  2 pivotal issue emerges consideration appeal w...
# 197  hardevinder singh v paramjit singh or 2013 ins...
# 198  judgement supreme court india civl appellate j...
# 199  tarun chatterjee harjit singh bedi civil appea...
#
# [200 rows x 3 columns]

# %%
query_document_relevance_pairings = query_document_relevance_pairings
query_document_relevance_pairings
# Out:
#      Current_Case_Name  Prior_Case_Name  Relevance
# 0    current_case_0051  prior_case_1593          1
# 1    current_case_0051  prior_case_0895          1
# 2    current_case_0051  prior_case_1463          1
# 3    current_case_0051  prior_case_1612          1
# 4    current_case_0051  prior_case_1644          1
# ..                 ...              ...        ...
# 995  current_case_0151  prior_case_1923          1
# 996  current_case_0151  prior_case_0846          1
# 997  current_case_0151  prior_case_0076          1
# 998  current_case_0151  prior_case_0886          1
# 999  current_case_0151  prior_case_1133          1
#
# [1000 rows x 3 columns]

# %%
documents_per_query = {}
queries_per_document = {}

relevant_pairings = pd.DataFrame(query_document_relevance_pairings.loc[query_document_relevance_pairings['Relevance'] == 1])

for idx, pair in relevant_pairings.iterrows():
    queryName, documentName = pair["Current_Case_Name"], pair["Prior_Case_Name"]
    if queryName not in documents_per_query:
        documents_per_query[queryName] = []
    if documentName not in queries_per_document:
        queries_per_document[documentName] = []
    documents_per_query[queryName].append(documentName)
    queries_per_document[documentName].append(queryName)

print(len(documents_per_query))
print(len(queries_per_document))
# Out:
# 200
# 815

# %%
# import statistics
from collections import Counter
import matplotlib.pyplot as plt

# Get the number of documents per query
num_documents_per_query = [len(docs) for docs in documents_per_query.values()]

# mode_value = statistics.mode(num_documents_per_query)

# Use Counter to find the mode and count occurrences
counter = Counter(num_documents_per_query)
mode_value = counter.most_common(1)[0][0]
num_queries_with_mode_value = counter[mode_value]

print(f"most common #documents for a query: {mode_value}")
print(f"number of queries with 'mode' documents: {num_queries_with_mode_value}")
print(f"total #queries: {len(documents_per_query)}")

# Plot the distribution
plt.bar(range(len(num_documents_per_query)), num_documents_per_query, align='center')
plt.xticks(range(len(num_documents_per_query)), documents_per_query.keys())
plt.xlabel('Queries')
plt.ylabel('Number of Documents')
plt.title('Distribution of Number of Documents per Query')
plt.show()
# Out:
# most common #documents for a query: 5
# number of queries with 'mode' documents: 200
# total #queries: 200

# %%
import matplotlib.pyplot as plt

# Get the number of documents per query
num_queries_per_document = [len(docs) for docs in queries_per_document.values()]

# Plot the distribution
plt.bar(range(len(num_queries_per_document)), num_queries_per_document, align='center')
plt.xticks(range(len(num_queries_per_document)), queries_per_document.keys())
plt.xlabel('Documents')
plt.ylabel('Number of Queries')
plt.title('Distribution of Number of Queries per Document')
plt.show()

# %%
print(max(num_documents_per_query))
print(max(num_queries_per_document))
# Out:
# 5
# 7
