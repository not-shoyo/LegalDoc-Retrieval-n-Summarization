# %%
# import json
# data = json.load(open('RR_Train.json'))

# %%
import pandas as pd
data = pd.read_csv('../../All_Data/Rhetorical_Role_Dataset/legal.csv')

# %%
data.columns
# Out:
# Index(['Text', 'Label', 'Type'], dtype='object')

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string

stop_words = set(stopwords.words('english'))
bow_labels = {}

for i,row in data.iterrows():
  if row['Label'] not in bow_labels:
    bow_labels[row['Label']] = {}
  labelled_text = row['Text'].translate(str.maketrans('', '', string.punctuation))
  labelled_text_words = word_tokenize(labelled_text)
  for word in labelled_text_words:
    if word not in stop_words:
      if word not in bow_labels[row['Label']].keys():
        bow_labels[row['Label']][word] = 1
      else:
        bow_labels[row['Label']][word] += 1

# %% [markdown]
# Creates a dictionary of rhetorical role labels and the corresponding words appearing in the labelled sentences with their frequencies.

# %%
print(bow_labels["PREAMBLE"])
print(len(bow_labels))
# Out:
# {'IN': 199, 'THE': 488, 'HIGH': 106, 'COURT': 189, 'OF': 675, 'KARNATAKA': 61, 'CIRCUIT': 2, 'BENCH': 40, 'AT': 106, 'GULBARGADATED': 1, 'THIS': 114, '22ND': 3, 'DAY': 66, 'FEBRUARY': 6, '2013': 18, 'BEFORETHE': 8, 'HONBLE': 79, 'MRJUSTICE': 20, 'ANAND': 8, 'BYRAREDDY': 6, 'CRIMINAL': 96, 'APPEAL': 87, 'NO3532': 1, '2012BETWEEN': 1, 'RBabu': 1, 'So': 103, 'Siddappa': 3, 'APPELLANTAge': 1, '30': 15, 'Years': 14, 'Occ': 36, 'HouseholdRo': 3, 'Sunthan': 1, 'VillageTaluk': 1, 'ChincholiDistrict': 1, 'GulbargaBy': 1, 'Shri': 60, 'Ishwar': 1, 'Raj': 3, 'SChowdapur': 1, 'AdvocateANDThe': 1, 'State': 191, 'Karnataka': 30, 'RESPONDENTThrough': 2, 'Ratkal': 1, 'Police': 64, 'StationRepresented': 6, 'Additional': 17, 'StatePublic': 2, 'Prosecutor': 25, 'Circuit': 3, 'BenchGulbargaBy': 1, 'SSAspalli': 1, 'Government': 62, 'Pleader': 5, 'This': 64, 'Criminal': 106, 'Appeal': 47, 'filed': 65, 'Section': 105, '3742': 7, 'theCode': 6, 'Procedure': 47, '1973': 26, 'advocate': 6, 'theappellant': 20, 'praying': 26, 'set': 43, 'aside': 30, 'order': 101, 'conviction': 40, 'andsentence': 2, 'SCNo2322008': 1, 'file': 12, 'II': 18, 'AdditionalSessions': 1, 'Judge': 79, 'Gulbarga': 3, 'acquit': 3, 'appellant': 177, 'appeal': 121, 'coming': 28, 'hearing': 12, 'day': 59, 'courtdelivered': 1, 'following': 32, 'JUDGMENT': 110, '111IN': 1, 'BENGALURU': 25, 'DATED': 59, '06TH': 1, 'JULY': 9, '2018': 21, 'PRESENT': 26, 'DrJUSTICE': 5, 'VINEET': 10, 'KOTHARI': 10, 'AND': 127, 'MrsJUSTICE': 5, 'SSUJATHA': 9, 'ITANo4152017BETWEEN1': 1, 'PR': 6, 'COMMISSIONER': 33, 'INCOME': 67, 'TAX7': 1, 'CR': 3, 'BUILDING': 9, 'QUEENS': 7, 'ROAD': 23, 'BANGALORE5600012': 1, 'DEPUTY': 6, 'TAX': 106, 'CIRCLE511': 1, 'BANGALORE': 20, 'APPELLANTSBy': 2, 'Mr': 132, 'EI': 2, 'SANMATHI': 2, 'ADVANDMS': 2, 'TESCO': 1, 'HINDUSTAN': 1, 'CENTRE': 1, 'PVT': 11, 'LTDNo81': 1, '82': 2, 'EPIP': 3, 'AREA': 2, 'RESEARCH': 2, 'CENTRE2WHITEFIELD': 1, 'BANGALORE560095PAN': 1, 'AABCT8915B': 1, 'RESPONDENTRESPONDETN': 1, 'SERVED': 2, 'UNREPRESENTED': 2, 'ITA': 36, 'IS': 24, 'FILED': 27, 'UNDER': 25, 'SECTION': 20, '260A': 7, 'INCOMETAX': 28, 'ACT': 13, '1961': 30, 'PRAYING': 14, 'TO': 25, 'DECIDE': 3, 'FOREGOINGQUESTION': 2, 'LAW': 7, 'ANDOR': 2, 'SUCH': 7, 'OTHER': 6, 'QUESTIONS': 6, 'LAWAS': 2, 'MAY': 6, 'BE': 4, 'FORMULATED': 3, 'BY': 45, 'ASDEEMED': 4, 'FIT': 6, 'SET': 9, 'ASIDE': 10, 'APPELLATE': 41, 'ORDER': 49, 'DATED25012017': 1, 'PASSED': 21, 'APPELLATETRIBUNAL': 1, 'B': 48, 'PROCEEDINGS': 3, 'Vs': 33, 'Ms': 44, 'Tesco': 1, 'Hindustan': 1, 'Centre': 4, 'Pvt': 10, 'Ltd': 94, '211NoITTPA': 1, 'No569Bang2015': 1, 'FOR': 51, 'ASSESSMENT': 10, 'YEAR': 8, '201011ANNEXUREA': 1, 'AS': 18, 'SOUGHT': 3, 'GRANT': 2, 'RELIEF': 3, 'DEEMED': 2, 'INTEREST': 4, 'JUSTICE': 70, 'COMING': 20, 'ON': 51, 'HEARING': 6, 'S': 78, 'SUJATHA': 7, 'J': 108, 'DELIVERED': 9, 'FOLLOWING': 19, 'DHARWAD': 19, '29TH': 3, 'JANUARY': 7, 'PRESENTTHE': 6, 'DR': 6, 'K': 24, 'BHAKTHAVATSALA': 1, 'BSREENIVASE': 2, 'GOWDA': 3, 'R': 84, 'C': 38, 'No112009': 1, 'CWCRIMINAL': 2, 'NOS25162009': 1, 'CW': 11, '25352009': 1, '25362009BETWEEN': 1, 'CRL': 5, 'RC': 2, 'NO112009High': 1, 'Court': 294, 'PetitionerRep': 1, 'By': 76, 'Registrar': 3, 'GeneralHigh': 2, 'BenchDharwadBy': 1, 'Sri': 133, 'V': 35, 'M': 85, 'Banakar': 4, 'Addl': 32, 'SPP': 10, 'petitionerAND': 1, '1': 212, 'SundreshSo': 2, 'Basavanneppa': 2, 'UdikeriAge': 9, '22': 16, 'years2': 4, 'ChandranaikRevannavarAge': 1, '28': 25, 'years3': 6, 'Sidlingappa': 2, 'MudakappaSo': 1, 'Chandranaik': 6, 'RevannavarAge': 7, '26': 24, 'years4': 2, 'Kalmesh': 1, 'Shankreppa': 2, 'UdkeriAge': 5, '23': 9, 'years5': 2, 'Rajshekhar': 2, 'Gangappa': 1, 'UdkeriSo': 1, 'Chanbasappa': 4, '40': 15, 'years6': 2, 'Bhagwant': 1, 'Nagappa': 3, '32': 15, 'years7': 3, 'MallanaikRevennavarAge': 1, '53': 11, 'years8': 2, 'Irappa': 1, 'Basavenneppa': 1, '20': 14, 'years': 217, '9': 16, 'Chanabasappa': 1, '55': 12, 'All': 18, 'appellants': 47, 'RespondentsResiding': 1, 'MurkibhaviTq': 2, 'BailhongalDist': ...
# 14

# %%
import heapq

freq_words_label = {}
for label in bow_labels.keys():
  freq_words = [(word, bow_labels[label][word]) for word in heapq.nlargest(30, bow_labels[label], key=bow_labels[label].get)]
  freq_words_label[label] = freq_words

# %% [markdown]
# Stores 30 most frequent words of each label in dictionary freq_words_label.

# %%
print(freq_words_label["PREAMBLE"])
# Out:
# [('OF', 675), ('The', 510), ('THE', 488), ('Court', 294), ('Act', 274), ('years', 217), ('1', 212), ('IN', 199), ('State', 191), ('2', 190), ('COURT', 189), ('appellant', 177), ('case', 164), ('v', 154), ('High', 154), ('3', 134), ('Sri', 133), ('Mr', 132), ('AND', 127), ('Commissioner', 127), ('appeal', 121), ('THIS', 114), ('Incometax', 114), ('JUDGMENT', 110), ('J', 108), ('HIGH', 106), ('AT', 106), ('Criminal', 106), ('TAX', 106), ('made', 106)]

# %%
unique_words = set()
for words_list in freq_words_label.values():
  words = [item[0] for item in words_list]
  unique_words.update(words)
print(len(unique_words))
# Out:
# 159

# %%
document_frequencies = {}
for words_list in freq_words_label.values():
  for item in words_list:
    if item[0] not in document_frequencies:
      document_frequencies[item[0]] = 0
    document_frequencies[item[0]] += 1

# %%
print(document_frequencies)
# Out:
# {'The': 13, 'accused': 9, 'case': 12, 'Court': 13, 'evidence': 5, 'Act': 11, 'In': 7, 'also': 6, 'It': 7, 'Section': 11, 'made': 8, 'said': 7, 'would': 5, 'stated': 2, 'prosecution': 4, 'assessee': 6, 'order': 10, 'High': 9, '1': 8, 'tax': 5, 'appellant': 7, 'may': 3, '2': 8, 'house': 2, 'one': 2, 'section': 4, 'time': 3, 'PW1': 1, 'question': 5, 'view': 3, 'learned': 4, 'submitted': 2, 'counsel': 3, 'petitioner': 5, 'State': 6, 'He': 3, 'contended': 2, 'Vs': 1, 'therefore': 3, 'Learned': 1, 'upon': 2, 'India': 1, 'respondent': 1, 'hand': 1, 'court': 4, 'suit': 1, 'bail': 2, 'deceased': 2, 'filed': 2, 'On': 1, 'dated': 3, 'appeal': 4, '3': 4, 'No': 3, 'complainant': 1, 'persons': 1, 'Whether': 1, 'facts': 2, 'law': 3, '4': 1, 'circumstances': 2, 'whether': 2, 'following': 2, 'Tribunal': 2, 'Ltd': 3, 'consideration': 1, 'proves': 1, 'holding': 1, 'committed': 1, 'place': 1, 'entitled': 1, 'points': 1, 'Text': 1, 'Signature': 1, 'J': 2, 'Appeal': 2, 'List': 1, 'Judgment': 1, 'JUDGE': 1, 'PW': 1, 'N': 1, 'judgment': 4, 'OF': 2, 'Sd': 1, 'S': 1, 'JURISDICTION': 1, 'delivered': 1, 'APPELLATE': 1, 'Criminal': 2, 'K': 1, 'Judge': 2, 'Civil': 1, 'v': 3, 'decision': 2, 'held': 3, 'Bench': 1, 'Commissioner': 3, 'two': 1, 'declaration': 1, 'statement': 1, 'Constitution': 1, 'Bombay': 1, 'cheque': 1, 'SCC': 1, 'must': 1, 'THE': 1, 'years': 1, 'IN': 1, 'COURT': 1, 'Sri': 1, 'Mr': 1, 'AND': 1, 'THIS': 1, 'Incometax': 1, 'JUDGMENT': 1, 'HIGH': 1, 'AT': 1, 'TAX': 1, 'We': 1, 'offence': 4, 'I': 2, 'opinion': 1, 'failed': 1, 'present': 1, 'imprisonment': 1, 'trial': 1, 'sentenced': 1, 'Code': 1, 'fine': 1, 'IPC': 1, 'convicted': 1, 'Indian': 1, 'Sessions': 1, 'Penal': 1, 'read': 1, 'shall': 2, 'dismissed': 1, 'allowed': 1, 'set': 1, 'costs': 1, 'aside': 1, 'sentence': 1, 'hereby': 1, 'accordingly': 1, 'result': 1, 'period': 1, 'person': 1, 'income': 1, 'subsection': 1, 'cooperative': 1, 'death': 1, 'b': 1, 'reads': 1, 'Government': 1, 'goods': 1, 'clause': 1, 'company': 1, 'society': 1, 'year': 1}

# %%
from collections import Counter
import numpy as np

tf_idf_weights = {}
i = 0
for words_list in freq_words_label.values():
  words_dict = {key: value for key, value in words_list}
  for word in unique_words:
    document_frequency = 1 if document_frequencies.get(word) == None else document_frequencies[word]
    tf = 0 if word not in words_dict else 1 + np.log2(words_dict[word])
    idf = np.log2(len(freq_words_label)/document_frequency)
    tf_idf_weights[i, word] = tf * idf
  i += 1

# %%
print(tf_idf_weights)
# Out:
# {(0, 'appellant'): 9.826548487290914, (0, 'two'): 0.0, (0, 'offence'): 0.0, (0, 'learned'): 0.0, (0, 'question'): 14.22656971647795, (0, 'delivered'): 0.0, (0, 'Bombay'): 0.0, (0, 'points'): 0.0, (0, 'persons'): 0.0, (0, 'shall'): 0.0, (0, 'trial'): 0.0, (0, 'subsection'): 0.0, (0, 'submitted'): 0.0, (0, 'allowed'): 0.0, (0, 'person'): 0.0, (0, 'reads'): 0.0, (0, 'held'): 0.0, (0, 'On'): 0.0, (0, 'said'): 10.400879436282183, (0, 'section'): 17.513265528373136, (0, 'Commissioner'): 0.0, (0, 'read'): 0.0, (0, 'JUDGE'): 0.0, (0, 'Judge'): 0.0, (0, 'Penal'): 0.0, (0, 'set'): 0.0, (0, 'Whether'): 0.0, (0, 'judgment'): 0.0, (0, 'TAX'): 0.0, (0, 'decision'): 0.0, (0, 'SCC'): 0.0, (0, 'time'): 21.495924775940054, (0, 'IN'): 0.0, (0, 'income'): 0.0, (0, 'Criminal'): 0.0, (0, 'appeal'): 0.0, (0, 'declaration'): 0.0, (0, 'List'): 0.0, (0, 'also'): 13.267003346943907, (0, 'made'): 8.398922961457709, (0, 'hand'): 0.0, (0, 'J'): 0.0, (0, 'AND'): 0.0, (0, 'Bench'): 0.0, (0, 'cheque'): 0.0, (0, 'COURT'): 0.0, (0, 'must'): 0.0, (0, 'goods'): 0.0, (0, 'evidence'): 16.69560118196984, (0, 'facts'): 0.0, (0, 'present'): 0.0, (0, 'accordingly'): 0.0, (0, 'convicted'): 0.0, (0, 'The'): 1.2937447814995964, (0, 'period'): 0.0, (0, 'K'): 0.0, (0, 'Code'): 0.0, (0, 'opinion'): 0.0, (0, '1'): 8.02476820185842, (0, '3'): 0.0, (0, 'Judgment'): 0.0, (0, 'counsel'): 0.0, (0, 'filed'): 0.0, (0, 'circumstances'): 0.0, (0, 'Act'): 3.801512996652312, (0, 'therefore'): 0.0, (0, 'Government'): 0.0, (0, 'Sessions'): 0.0, (0, 'case'): 2.567727277927493, (0, 'company'): 0.0, (0, 'THE'): 0.0, (0, 'AT'): 0.0, (0, 'State'): 0.0, (0, 'We'): 0.0, (0, 'imprisonment'): 0.0, (0, 'society'): 0.0, (0, 'N'): 0.0, (0, 'IPC'): 0.0, (0, 'It'): 10.768184324776927, (0, 'prosecution'): 18.36704798790431, (0, 'HIGH'): 0.0, (0, 'Section'): 3.6950219647403992, (0, 'tax'): 14.62940872639801, (0, 'No'): 0.0, (0, 'b'): 0.0, (0, 'entitled'): 0.0, (0, 'PW1'): 36.63456635510056, (0, 'whether'): 0.0, (0, 'petitioner'): 0.0, (0, 'JURISDICTION'): 0.0, (0, 'Text'): 0.0, (0, 'THIS'): 0.0, (0, '4'): 0.0, (0, 'In'): 10.909893083770042, (0, 'He'): 0.0, (0, 'dismissed'): 0.0, (0, 'accused'): 7.418110175616812, (0, 'Indian'): 0.0, (0, 'upon'): 0.0, (0, 'cooperative'): 0.0, (0, 'Signature'): 0.0, (0, 'Vs'): 0.0, (0, 'view'): 21.25952599652636, (0, 'Constitution'): 0.0, (0, 'assessee'): 12.369316879247323, (0, 'statement'): 0.0, (0, 'fine'): 0.0, (0, 'death'): 0.0, (0, 'PW'): 0.0, (0, 'Incometax'): 0.0, (0, 'proves'): 0.0, (0, 'place'): 0.0, (0, 'stated'): 28.73612482388219, (0, 'bail'): 0.0, (0, 'hereby'): 0.0, (0, 'clause'): 0.0, (0, 'court'): 0.0, (0, 'following'): 0.0, (0, 'suit'): 0.0, (0, 'failed'): 0.0, (0, 'year'): 0.0, (0, '2'): 7.8566283178109195, (0, 'contended'): 0.0, (0, 'S'): 0.0, (0, 'sentenced'): 0.0, (0, 'Learned'): 0.0, (0, 'Ltd'): 0.0, (0, 'OF'): 0.0, (0, 'JUDGMENT'): 0.0, (0, 'sentence'): 0.0, (0, 'holding'): 0.0, (0, 'Appeal'): 0.0, (0, 'Sd'): 0.0, (0, 'law'): 0.0, (0, 'years'): 0.0, (0, 'aside'): 0.0, (0, 'deceased'): 0.0, (0, 'Court'): 1.2215292880914281, (0, 'committed'): 0.0, (0, 'I'): 0.0, (0, 'house'): 27.309725369502843, (0, 'Mr'): 0.0, (0, 'APPELLATE'): 0.0, (0, 'may'): 21.774248721877097, (0, 'High'): 6.337656231854779, (0, 'one'): 27.280966737258577, (0, 'order'): 4.906948954426617, (0, 'complainant'): 0.0, (0, 'Sri'): 0.0, (0, 'consideration'): 0.0, (0, 'Tribunal'): 0.0, (0, 'result'): 0.0, (0, 'would'): 15.43383570637118, (0, 'respondent'): 0.0, (0, 'costs'): 0.0, (0, 'Civil'): 0.0, (0, 'India'): 0.0, (0, 'v'): 0.0, (0, 'dated'): 0.0, (1, 'appellant'): 7.614709844115208, (1, 'two'): 0.0, (1, 'offence'): 0.0, (1, 'learned'): 15.648461139567125, (1, 'question'): 0.0, (1, 'delivered'): 0.0, (1, 'Bombay'): 0.0, (1, 'points'): 0.0, (1, 'persons'): 0.0, (1, 'shall'): 0.0, (1, 'trial'): 0.0, (1, 'subsection'): 0.0, (1, 'submitted'): 24.05862632337085, (1, 'allowed'): 0.0, (1, 'person'): 0.0, (1, 'reads'): 0.0, (1, 'held'): 0.0, (1, 'On'): 0.0, (1, 'said'): 7.754887502163468, (1, ...

# %%
counter = Counter(tf_idf_weights)
highest_weight_100 = counter.most_common(100)
highest_weight_100 = dict(highest_weight_100)

print(highest_weight_100)
# Out:
# {(9, 'THE'): 37.80984168183129, (0, 'PW1'): 36.63456635510056, (3, 'On'): 36.36308278265473, (4, 'Whether'): 33.72547754129168, (3, 'complainant'): 33.581551785980395, (3, 'persons'): 33.48346253536957, (9, 'years'): 33.358335209707356, (9, 'IN'): 32.88269525899075, (6, 'Signature'): 32.742920488967556, (9, 'COURT'): 32.59949583770853, (12, 'dismissed'): 30.751303617983112, (9, 'Sri'): 30.669319229369624, (13, 'person'): 30.669319229369624, (9, 'Mr'): 30.627863545310657, (11, 'imprisonment'): 30.501585522657756, (9, 'AND'): 30.415757962948213, (12, 'allowed'): 29.87056516141703, (9, 'THIS'): 29.822592349365983, (9, 'Incometax'): 29.822592349365983, (6, 'List'): 29.72537119074668, (9, 'JUDGMENT'): 29.626398205588863, (9, 'TAX'): 29.422935979950832, (9, 'AT'): 29.422935979950832, (9, 'HIGH'): 29.422935979950832, (12, 'set'): 29.37087064164692, (8, 'SCC'): 29.318307062872357, (6, 'Judgment'): 29.21164638987467, (9, 'OF'): 29.19296428677815, (6, 'JUDGE'): 28.763001048556358, (0, 'stated'): 28.73612482388219, (8, 'must'): 28.644870644799006, (6, 'PW'): 28.584838877158205, (11, 'trial'): 27.945414035647296, (6, 'N'): 27.877178971021255, (12, 'costs'): 27.66723550325668, (11, 'sentenced'): 27.595432493026166, (1, 'Vs'): 27.522678421921494, (13, 'income'): 27.448947756972142, (11, 'Code'): 27.374213922982477, (13, 'subsection'): 27.374213922982477, (0, 'house'): 27.309725369502843, (6, 'Sd'): 27.29844924502526, (0, 'one'): 27.280966737258577, (11, 'fine'): 27.22162488691333, (12, 'aside'): 27.143710785307103, (11, 'IPC'): 27.064675579081218, (3, 'filed'): 27.063589071544694, (6, 'S'): 26.984486533534852, (11, 'convicted'): 26.984486533534852, (11, 'Indian'): 26.73664665743278, (13, 'cooperative'): 26.651484454403228, (6, 'delivered'): 26.564981059311112, (6, 'JURISDICTION'): 26.564981059311112, (11, 'Sessions'): 26.564981059311112, (2, 'respondent'): 26.4770935513063, (6, 'APPELLATE'): 26.4770935513063, (1, 'Learned'): 26.38777691565847, (12, 'sentence'): 26.38777691565847, (1, 'India'): 26.29698390530347, (11, 'Penal'): 26.29698390530347, (13, 'death'): 26.29698390530347, (10, 'We'): 26.204664890753364, (4, '4'): 26.110767697176467, (11, 'read'): 26.110767697176467, (12, 'hereby'): 26.110767697176467, (12, 'accordingly'): 26.01523742730838, (13, 'reads'): 25.918016268689076, (13, 'Government'): 25.918016268689076, (13, 'b'): 25.918016268689076, (3, 'deceased'): 25.908569575540824, (13, 'goods'): 25.718254179307475, (3, 'house'): 25.657964474554987, (6, 'K'): 25.615581057893227, (12, 'result'): 25.615581057893227, (13, 'clause'): 25.615581057893227, (3, 'one'): 25.600104104463586, (13, 'shall'): 25.600104104463586, (6, 'Civil'): 25.404291467817064, (10, 'opinion'): 25.404291467817064, (12, 'period'): 25.404291467817064, (13, 'company'): 25.404291467817064, (13, 'society'): 25.404291467817064, (13, 'year'): 25.184548082974928, (3, 'stated'): 24.88491660323001, (2, 'hand'): 24.8375157227414, (10, 'failed'): 24.337821202971295, (10, 'present'): 24.20545691701985, (6, 'J'): 24.07988703898495, (1, 'submitted'): 24.05862632337085, (4, 'consideration'): 23.93075707509697, (12, 'shall'): 23.655515833673444, (2, 'suit'): 23.49109432296766, (4, 'proves'): 23.49109432296766, (4, 'holding'): 23.336355863249498, (4, 'committed'): 23.336355863249498, (4, 'place'): 23.177131611477247, (4, 'entitled'): 23.013153701195446, (4, 'points'): 22.844129532345626, (6, 'Appeal'): 22.129376763449127, (0, 'may'): 21.774248721877097}

# %%
highest_weight_words = []
for i in highest_weight_100.keys():
  highest_weight_words.append(i[1])

highest_weight_words = list(set(highest_weight_words))
highest_weight_words.append("ALL CAPS")
print(highest_weight_words)
# Out:
# ['delivered', 'points', 'persons', 'shall', 'trial', 'subsection', 'submitted', 'allowed', 'person', 'reads', 'On', 'read', 'JUDGE', 'set', 'Penal', 'Whether', 'TAX', 'SCC', 'IN', 'income', 'List', 'hand', 'J', 'AND', 'COURT', 'must', 'goods', 'accordingly', 'present', 'convicted', 'period', 'K', 'Code', 'opinion', 'Judgment', 'filed', 'Government', 'Sessions', 'company', 'THE', 'AT', 'We', 'imprisonment', 'society', 'N', 'IPC', 'HIGH', 'b', 'entitled', 'PW1', 'JURISDICTION', 'THIS', '4', 'dismissed', 'Indian', 'cooperative', 'Signature', 'Vs', 'fine', 'death', 'PW', 'Incometax', 'proves', 'place', 'stated', 'hereby', 'clause', 'suit', 'failed', 'year', 'sentenced', 'S', 'Learned', 'OF', 'JUDGMENT', 'sentence', 'holding', 'Sd', 'Appeal', 'years', 'aside', 'deceased', 'committed', 'house', 'Mr', 'APPELLATE', 'may', 'one', 'Sri', 'complainant', 'consideration', 'result', 'respondent', 'costs', 'Civil', 'India', 'ALL CAPS']

# %% [markdown]
# highest_weight_words = ['delivered', 'points', 'persons', 'shall', 'trial', 'subsection', 'submitted', 'allowed', 'person', 'reads', 'On', 'read', 'JUDGE', 'set', 'Penal', 'Whether', 'TAX', 'SCC', 'IN', 'income', 'List', 'hand', 'J', 'AND', 'COURT', 'must', 'goods', 'accordingly', 'present', 'convicted', 'period', 'K', 'Code', 'opinion', 'Judgment', 'filed', 'Government', 'Sessions', 'company', 'THE', 'AT', 'We', 'imprisonment', 'society', 'N', 'IPC', 'HIGH', 'b', 'entitled', 'PW1', 'JURISDICTION', 'THIS', '4', 'dismissed', 'Indian', 'cooperative', 'Signature', 'Vs', 'fine', 'death', 'PW', 'Incometax', 'proves', 'place', 'stated', 'hereby', 'clause', 'suit', 'failed', 'year', 'sentenced', 'S', 'Learned', 'OF', 'JUDGMENT', 'sentence', 'holding', 'Sd', 'Appeal', 'years', 'aside', 'deceased', 'committed', 'house', 'Mr', 'APPELLATE', 'may', 'one', 'Sri', 'complainant', 'consideration', 'result', 'respondent', 'costs', 'Civil', 'India', 'ALL CAPS']
